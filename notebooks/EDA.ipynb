# %% [markdown]
# # Exploratory Data Analysis
#
# This notebook runs the reproducible EDA workflow and saves the class-distribution, feature-distribution, correlation, boxplot, and pairplot figures to `results/`.

# %%
from pathlib import Path
import runpy

project_root = Path.cwd()
if not (project_root / 'Athlete.xlsx').exists():
    project_root = project_root.parent
runpy.run_path(str(project_root / 'notebooks' / 'EDA.py'), run_name='__main__')
