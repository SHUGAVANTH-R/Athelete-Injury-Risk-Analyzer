# %% [markdown]
# # Model Evaluation
#
# This notebook evaluates the saved DNN on the held-out test set, generates metrics and figures, and compares the DNN with a Logistic Regression baseline.

# %%
from pathlib import Path
import runpy

project_root = Path.cwd()
if not (project_root / 'models' / 'best_model.keras').exists():
    project_root = project_root.parent
runpy.run_path(str(project_root / 'notebooks' / 'Evaluation.py'), run_name='__main__')
